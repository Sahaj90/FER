# %%
pip install FER
# Out:
# Requirement already satisfied: FER in c:\users\sahaj\anaconda3\lib\site-packages (22.0.1)
# Requirement already satisfied: pandas in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (1.3.4)
# Requirement already satisfied: keras>=2.0.0 in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (3.4.3)
# Requirement already satisfied: mtcnn>=0.1.1 in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (0.1.1)
# Requirement already satisfied: requests in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (2.26.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (4.5.5.62)
# Requirement already satisfied: tqdm in c:\users\sahaj\anaconda3\lib\site-packages (from FER) (4.62.3)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\sahaj\anaconda3\lib\site-packages (from mtcnn>=0.1.1->FER) (4.5.5.62)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\sahaj\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn>=0.1.1->FER) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahaj\anaconda3\lib\site-packages (from matplotlib->FER) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sahaj\anaconda3\lib\site-packages (from matplotlib->FER) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sahaj\anaconda3\lib\site-packages (from matplotlib->FER) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahaj\anaconda3\lib\site-packages (from matplotlib->FER) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sahaj\anaconda3\lib\site-packages (from matplotlib->FER) (8.4.0)
# Requirement already satisfied: six in c:\users\sahaj\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->FER) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sahaj\anaconda3\lib\site-packages (from pandas->FER) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sahaj\anaconda3\lib\site-packages (from requests->FER) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sahaj\anaconda3\lib\site-packages (from requests->FER) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sahaj\anaconda3\lib\site-packages (from requests->FER) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sahaj\anaconda3\lib\site-packages (from requests->FER) (3.2)
# Requirement already satisfied: colorama in c:\users\sahaj\anaconda3\lib\site-packages (from tqdm->FER) (0.4.4)

# %%
from fer import FER
import matplotlib.pyplot as plt 


test_image_one = plt.imread("D:\SGP\SGP5\Image\Angry\download.jpg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)

# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002552349E280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002551BEC8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [{'box': (136, 56, 98, 98), 'emotions': {'angry': 0.88, 'disgust': 0.0, 'fear': 0.01, 'happy': 0.08, 'sad': 0.01, 'surprise': 0.0, 'neutral': 0.01}}]
# angry 0.88
